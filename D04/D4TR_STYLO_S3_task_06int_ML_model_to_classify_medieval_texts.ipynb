# %% [markdown]
# # Intermediate

# %% [markdown]
# ## Task 03: Develop a machine learning model to classify medieval texts by genre (e.g., poetry, prose, drama).
#
# Train a classifier (e.g., logistic regression, support vector machine) on labeled data to predict the genre of new texts. The code demonstrates genre classification of medieval-style texts (poetry, prose, and drama) using machine learning. It utilizes a logistic regression model with TF-IDF vectorization to represent text features and then evaluates the model's performance through classification metrics and visualization.
#
# Hints:
# - Preprocess the texts to extract relevant features, such as vocabulary, syntax, or stylistic markers.
# - Evaluate the model's performance on a separate test set to ensure its accuracy.
#
# **Libraries:**
#
# * **numpy:** For numerical operations.
# * **pandas:** For data manipulation and analysis.
# * **matplotlib.pyplot:** For plotting.
# * **sklearn:**
#     * `model_selection`: For splitting data into training and testing sets.
#     * `feature_extraction.text`: For TF-IDF vectorization.
#     * `linear_model`: For logistic regression.
#     * `metrics`: For evaluating model performance.
#     * `preprocessing`: For label encoding.
# * **seaborn:** For enhanced data visualization.
#
# **Code Walkthrough:**
#
# 1. **Data Preparation:**
#    * Create a sample dataset of medieval-style texts and their corresponding genres.
#    * Split the data into training and testing sets using `train_test_split`.
#
# 2. **Feature Extraction:**
#    * Use `TfidfVectorizer` to convert text into numerical features based on word importance (TF-IDF).
#    * This step transforms the text data into a sparse matrix where each row represents a text and each column represents a unique word.
#
# 3. **Model Training:**
#    * Train a logistic regression model using `LogisticRegression`.
#    * The `multi_class='ovr'` parameter indicates a one-vs-rest strategy for multi-class classification.
#
# 4. **Model Evaluation:**
#    * Make predictions on the test set.
#    * Print a classification report (`classification_report`) showing precision, recall, F1-score, and support for each genre.
#    * Generate a confusion matrix (`confusion_matrix`) to visualize the model's performance, indicating correct and incorrect predictions.
#    * Visualize the top 10 most important features using a bar plot. The importance of a feature is determined by summing the absolute values of its coefficients across all classes in the logistic regression model.
#
# 5. **Genre Prediction Function:**
#    * Define a function `predict_genre` that takes a new text as input, vectorizes it using the fitted TF-IDF vectorizer, and then uses the trained model to predict its genre and probabilities for each class.
#
# **Key Points:**
#
# * **TF-IDF Vectorization:** This technique weighs terms based on their frequency in a document and inverse frequency across the corpus, highlighting terms that are distinctive to a particular text.
# * **Logistic Regression:** This is a common model for text classification tasks due to its interpretability and efficiency.
# * **Classification Metrics:** The code provides a comprehensive evaluation of the model's performance using various metrics like precision, recall, F1-score, and confusion matrix.
# * **Feature Importance:** Visualizing the most important features can provide insights into the words or phrases that are most indicative of each genre.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# Some dummy data, but we have suitable dataset for this task
texts = [
    "In fields of gold, the sunlight gleams, A knight's brave heart with honor teems.",
    "Forsooth, the castle stood tall and grand, A symbol of power throughout the land.",
    "Act I: The jester enters, his bells do ring, With mirth and jest, the court doth sing.",
    "The dragon's breath, a fiery gale, The hero's sword shall soon prevail.",
    "Upon the stage, the players stride, To tell a tale of love and pride.",
    "The chronicle speaks of kings long past, Their deeds in history's pages cast.",
    "Roses are red, violets blue, My love for thee shall e'er be true.",
    "Hear ye, hear ye, the town crier calls, News of import within these walls.",
    "Scene II: The witch's cauldron bubbles high, As Macbeth's fate draws ever nigh.",
    "In days of yore, when magic reigned, A wizard's tome great power contained."
]

genres = ['poetry', 'prose', 'drama', 'poetry', 'drama', 'prose', 'poetry', 'prose', 'drama', 'prose']

# Create a DataFrame
df = pd.DataFrame({'text': texts, 'genre': genres})

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['genre'], test_size=0.3, random_state=42)


"PREPROCESS THE TEXT DATA USING TF-IDF VECTORIZATION"
"HERE"


# Train a logistic regression model
model = LogisticRegression(random_state=42, multi_class='ovr')
model.fit(X_train_tfidf, y_train)

"MAKE A PREDICTION ON THE TEST SET"
y_pred = "HERE"

# Print classification report
print(classification_report(y_test, y_pred))

# Create confusion matrix
cm = confusion_matrix(y_test, y_pred)
labels = sorted(df['genre'].unique())

# Visualize confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Visualize feature importance
feature_importance = pd.DataFrame({
    'feature': tfidf_vectorizer.get_feature_names_out(),
    'importance': model.coef_.sum(axis=0)
})
feature_importance = feature_importance.sort_values('importance', ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x='importance', y='feature', data=feature_importance.head(10))
plt.title('Top 10 Most Important Features')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# Function to predict genre of new text
def predict_genre(text):
    text_tfidf = tfidf_vectorizer.transform([text])
    prediction = model.predict(text_tfidf)
    probabilities = model.predict_proba(text_tfidf)
    return prediction[0], probabilities[0]

# Example usage
new_text = "Alas, poor Yorick! I knew him, Horatio, a fellow of infinite jest."
predicted_genre, probabilities = predict_genre(new_text)
print(f"Predicted genre: {predicted_genre}")
print("Probabilities:")
for genre, prob in zip(model.classes_, probabilities):
    print(f"{genre}: {prob:.2f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# ## Solution

# %% [markdown]
# 1:
# ```
# tfidf_vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
# X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
# X_test_tfidf = tfidf_vectorizer.transform(X_test)
# ```
#
# 2:
#
# `y_pred = model.predict(X_test_tfidf)`
