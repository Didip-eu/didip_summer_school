# %% [markdown]
# # Beginner

# %% [markdown]
# ## Task 02: Compare topic distributions between Old English poetry and prose (or any other text)
#
# Description: Separate your corpus into poetry and prose, and then compare the prevalence of different topics in each.
#
# Hints:
#
# - Use the same model and dictionary for both corpora.
# - Visualize the differences using a bar chart or heatmap.
#
#
# **Goal:**
#
# This code aims to uncover latent topics within Old English poetry and prose, and then compare how these topics are distributed across the two genres or any other topics.
#
# **Libraries:**
#
# * **nltk (Natural Language Toolkit):**
#     * `stopwords`: Filters out common words.
#     * `tokenize`: Splits text into words (tokens).
#     * `stem`: Reduces words to their root form.
# * **gensim:**
#     * `corpora`: Tools for creating a dictionary and text corpus.
#     * `models.LdaMulticore`: Implementation of Latent Dirichlet Allocation (LDA), our topic model.
# * **string:**  Handles string manipulations (like removing punctuation).
# * **numpy:** Performs numerical calculations (for averaging).
# * **matplotlib.pyplot:**  Visualizes results with a bar chart.
#
# **Code Breakdown:**
#
# 1. **Data Loading and Preprocessing:**
#    * Load sample Old English texts.
#    * The `preprocess` function:
#       * Tokenizes text.
#       * Converts to lowercase.
#       * Removes punctuation and numbers.
#       * Removes English stop words (consider using Old English stop words instead).
#       * Lemmatizes words.
#
# 2. **Topic Modeling with LDA:**
#    * Combine preprocessed texts.
#    * Create a dictionary mapping words to IDs.
#    * Build a corpus representing each text as word frequencies.
#    * Train the LDA model to find `num_topics` (set to 5) within the corpus.
#    * Calculate the average topic distribution for poetry and prose separately.
#
# 3. **Visualization and Results:**
#    * Generate a bar chart comparing the average topic probability in poetry vs. prose.
#    * Print the top words associated with each topic to understand their themes.
#
# **Enhancements for Old English:**
#
# * **Stop Words:** Use a list of Old English stop words for more accurate filtering.
# * **Lemmatization:** Employ a specialized Old English lemmatizer for better word normalization.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import gensim
from gensim import corpora
import string
import numpy as np
import "THE NAME OF THE PACKAGE IS MISSING" as plt

# Download necessary NLTK data
"THREE PACKAGES IS MISSING FROM HEre"

# Sample Old English texts (replace with your actual texts)
poetry = [
    "Hwæt! We Gardena in geardagum, þeodcyninga, þrym gefrunon, hu ða æþelingas ellen fremedon.",
    "Oft Scyld Scefing sceaþena þreatum, monegum mægþum, meodosetla ofteah, egsode eorlas.",
    # Add more poetry texts here
]

prose = [
    "Ær þam þe hit ealles ware, þa wæs se Ælmihtiga God, and he wæs æfre God.",
    "On anginne gesceop God heofonan and eorðan.",
    # Add more prose texts here
]

# Preprocessing function
def preprocess(text):
    "WRITE A PREPROCESS FUNCTION"
    return tokens

# Preprocess all texts
processed_poetry = [preprocess(text) for text in poetry]
processed_prose = [preprocess(text) for text in prose]

# Combine all texts for dictionary and model creation
all_texts = processed_poetry + processed_prose

# Create dictionary
dictionary = corpora.Dictionary(all_texts)

# Create corpus
corpus = "HOW DO WE CREATE A CORPUS"

# Train LDA model
num_topics = 5  # You can adjust this
lda_model = gensim.models.LdaMulticore(corpus=corpus, id2word=dictionary, num_topics=num_topics)

# Function to get average topic distribution
def get_avg_topic_dist(texts):
    corpus = [dictionary.doc2bow(text) for text in texts]
    topic_dists = [dict(lda_model.get_document_topics(doc)) for doc in corpus]
    avg_dist = {i: np.mean([dist.get(i, 0) for dist in topic_dists]) for i in range(num_topics)}
    return avg_dist

# Get average topic distributions
poetry_dist = get_avg_topic_dist(processed_poetry)
prose_dist = get_avg_topic_dist(processed_prose)

# Prepare data for visualization
topics = range(num_topics)
poetry_scores = [poetry_dist[i] for i in topics]
prose_scores = [prose_dist[i] for i in topics]

# Create bar chart
width = 0.35
fig, ax = "CREATE A BAR CHART"

ax.bar(np.array(topics) - width/2, poetry_scores, width, label='Poetry')
ax.bar(np.array(topics) + width/2, prose_scores, width, label='Prose')

ax.set_xlabel('Topics')
ax.set_ylabel('Average Topic Probability')
ax.set_title('Comparison of Topic Distributions in Old English Poetry and Prose')
ax.set_xticks(topics)
ax.legend()

plt.tight_layout()
plt.show()

# Print top words for each topic
print("Top words for each topic:")
for idx, topic in lda_model.print_topics(-1):
    print(f"Topic: {idx} \nWords: {topic}\n")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# WARNING:gensim.models.ldamulticore:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# Top words for each topic:
# Topic: 0
# Words: 0.095*"god" + 0.095*"anginne" + 0.095*"heofonan" + 0.095*"eorðan" + 0.095*"gesceop" + 0.016*"wæs" + 0.016*"gefrunon" + 0.016*"gardena" + 0.016*"þreatum" + 0.016*"ða"
#
# Topic: 1
# Words: 0.026*"god" + 0.026*"gesceop" + 0.026*"anginne" + 0.026*"eorðan" + 0.026*"heofonan" + 0.026*"wæs" + 0.026*"scyld" + 0.026*"þeodcyninga" + 0.026*"gardena" + 0.026*"eorlas"
#
# Topic: 2
# ...

# %% [markdown]
# ## Solution

# %% [markdown]
# 1: import matplotlib.pyplot as plt
#
# 2: nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')
#
# 3: def preprocess(text):
#     tokens = word_tokenize(text.lower())
#     tokens = [token for token in tokens if token not in string.punctuation and not token.isdigit()]
#     stop_words = set(stopwords.words('english'))
#     tokens = [token for token in tokens if token not in stop_words]
#     lemmatizer = WordNetLemmatizer()
#     tokens = [lemmatizer.lemmatize(token) for token in tokens]
#     return tokens
#
# 4: corpus = [dictionary.doc2bow(text) for text in all_texts]
#
# 5: fig, ax = plt.subplots(figsize=(12, 6))
